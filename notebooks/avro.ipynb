# %%
import io
from typing import Iterator

from google.cloud import storage
from fastavro import reader
import tensorflow as tf
tf.compat.v1.enable_eager_execution()

sys.path.append('mlp_trainer')
from trainer import avro_data as data

dataset = tf.data.Dataset.from_generator(
    data.list_blobs,
    (tf.string, tf.string),
    # output_shapes=(tf.TensorShape([]), tf.TensorShape([])),
    args = (            "gcp-cert-demo-1",
        'data/avro/1_pct/test/')
).interleave(lambda obj_name, bucket_name: 
    tf.data.Dataset.from_generator(
        data.generate_blob,
        (tf.float64, tf.uint16),
        args=(obj_name, bucket_name)
    ).prefetch(buffer_size=tf.data.experimental.AUTOTUNE),
    num_parallel_calls=tf.data.experimental.AUTOTUNE,
    cycle_length=tf.data.experimental.AUTOTUNE,
).prefetch(buffer_size=tf.data.experimental.AUTOTUNE).batch(2).repeat(2)

count = 0
for value in dataset.take(1):
    # if count % 100000 == 0:
    print(value)
    count += 1
# Out:
# /home/erik/anaconda3/lib/python3.7/site-packages/google/auth/_default.py:69: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK. We recommend that most server applications use service accounts instead. If your application continues to use end user credentials from Cloud SDK, you might receive a "quota exceeded" or "API not enabled" error. For more information about service accounts, see https://cloud.google.com/docs/authentication/
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# ...
